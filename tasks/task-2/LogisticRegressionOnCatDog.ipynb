# %% [markdown]
# # Logistic regression on cats vs dogs

# %% [markdown]
# Lots of important things to be imported

# %%
import numpy as np
import matplotlib.pyplot as plt
import data
import cv2
import os
import random
import pickle

# %% [markdown]
# ### Quick note:
#     DO NOT RUN THE FOLLOWING CODE UNLESS YOU WANT TO RELOAD THE DATA
#     This bit of code goes through the ./data folder and picks up all the images, reads as grayscale, resizes the images, and stores them in X.pickle and Y.pickle. Use the provided load_from_pickle() to get X and y

# %% [markdown]
# ```python
# DataDir = "./data/"
# Categories = ["Dogs", "Cats"]
# ImgSize = 48
# training_data = []
# X = []
# Y = []
#
# for category in Categories:
#     path = os.path.join(DataDir, category)
#     for img in os.listdir(path):
#         img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
#         plt.imshow(img_array, cmap="gray")
#         plt.show()
#         break
#     break
#
# new_array = cv2.resize(img_array, (ImgSize, ImgSize))
# plt.imshow(new_array, cmap = "gray")
# plt.show()
#
# def create_training_data():
#     for category in Categories:
#         path = os.path.join(DataDir, category)
#         class_num = Categories.index(category)
#         for img in os.listdir(path):
#             try:
#                 img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
#                 new_array = cv2.resize(img_array, (ImgSize, ImgSize))
#                 training_data.append([new_array, class_num])
#
#             except Exception as e:
#                 pass
#
# create_training_data()
# random.shuffle(training_data)
#
# for features, label in training_data:
#     X.append(features)
#     Y.append(label)
#
# X = np.array(X).reshape(-1, ImgSize, ImgSize, 1)
# Y = np.array(Y).reshape(-1, 1)
#
# pickle_out = open("X.pickle", "wb")
# pickle.dump(X, pickle_out)
# pickle_out.close()
#
# pickle_out = open("Y.pickle", "wb")
# pickle.dump(Y, pickle_out)
# pickle_out.close()
# ```

# %%
def load_from_pickle():
    pickle_in = open("X.pickle", "rb")
    X = pickle.load(pickle_in)

    pickle_in = open("Y.pickle", "rb")
    Y = pickle.load(pickle_in)
    
    return X, Y

# %%
X, y = load_from_pickle()

# %%
print(X.shape, y.shape)
# Out:
# (10028, 48, 48, 1) (10028, 1)

# %%
for sample in X[:10]:
    plt.imshow(sample.reshape(48,48), cmap="gray")
    plt.show()

# %%
sample.reshape(48, 48)
# Out:
# array([[ 78,  76,  98, ...,  57,  69,  77],
#        [ 87,  89,  81, ...,  96,  92,  71],
#        [ 91, 103, 103, ..., 128,  77,  55],
#        ...,
#        [184, 187, 188, ..., 177, 178, 176],
#        [180, 185, 186, ..., 179, 178, 181],
#        [179, 183, 189, ..., 182, 181, 183]], dtype=uint8)
